# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#data sources
data = "Resources/data.csv"
data_by_artist = "Resources/data_by_artist.csv"
data_by_genres = "Resources/data_by_genres.csv"
data_by_year = "Resources/data_by_year.csv"
data_w_genres = "Resources/data_w_genres.csv"

# %%
data_df = pd.read_csv(data)
data_df.head(2)
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
#
#    key  liveness  loudness  mode                                      name  \
# 0   10    0.1510   -12.428     1               Singende Bataillone 1. Teil
# 1    8    0.0763   -28.454     1  Fantasiestücke, Op. 111: Più tosto lento
#
#    popularity release_date  speechiness    tempo  valence  year
# 0           0         1928       0.0506  118.469   0.7790  1928
# 1           0         1928       0.0462   83.972   0.0767  1928

# %%
data_by_artist_df = pd.read_csv(data_by_artist)
data_by_artist_df.head(2)
# Out:
#                             artists  acousticness  danceability  duration_ms  \
# 0  "Cats" 1981 Original London Cast      0.575083      0.442750     247260.0
# 1         "Cats" 1983 Broadway Cast      0.862538      0.441731     287280.0
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.386336          0.022717  0.287708 -14.205417     0.180675  115.983500
# 1  0.406808          0.081158  0.315215 -10.690000     0.176212  103.044154
#
#     valence  popularity  key  mode  count
# 0  0.334433   38.000000    5     1     12
# 1  0.268865   33.076923    5     1     26

# %%
data_by_genres_df = pd.read_csv(data_by_genres)
data_by_genres_df.head(2)
# Out:
#   genres  acousticness  danceability   duration_ms    energy  \
# 0  432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1     []      0.679245      0.521473  2.298526e+05  0.401522
#
#    instrumentalness  liveness   loudness  speechiness       tempo  valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.22175
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.51592
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1

# %%
data_by_year_df = pd.read_csv(data_by_year)
data_by_year_df.head(2)
# Out:
#    year  acousticness  danceability    duration_ms    energy  \
# 0  1921      0.895823      0.425661  229911.914062  0.236784
# 1  1922      0.939236      0.480000  167904.541667  0.237026
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0           0.32233  0.215814 -17.095437     0.077258  100.397758  0.425495
# 1           0.44047  0.238647 -19.179958     0.115419  101.376139  0.534056
#
#    popularity  key  mode
# 0    0.351562    7     1
# 1    0.138889   10     1

# %%
data_w_genres_df = pd.read_csv(data_w_genres)
data_w_genres_df.head(2)
# Out:
#                             artists  acousticness  danceability  duration_ms  \
# 0  "Cats" 1981 Original London Cast      0.575083      0.442750     247260.0
# 1         "Cats" 1983 Broadway Cast      0.862538      0.441731     287280.0
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.386336          0.022717  0.287708 -14.205417     0.180675  115.983500
# 1  0.406808          0.081158  0.315215 -10.690000     0.176212  103.044154
#
#     valence  popularity  key  mode  count          genres
# 0  0.334433   38.000000    5     1     12  ['show tunes']
# 1  0.268865   33.076923    5     1     26              []
