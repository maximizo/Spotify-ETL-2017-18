# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

#data sources
data_2018 = "Resources/top2018.csv"
data_2017 = "Resources/top2017.csv"

# %%
data_2017 = pd.read_csv(data_2017)
data_2017.head(5)
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.5810          0.000000    0.0931    0.931   95.977     233713.0
# 1        0.2290          0.000000    0.0924    0.813   88.931     228827.0
# 2        0.2090          0.000000    0.1120    0.846  177.833     228200.0
# 3        0.0498          0.000014    0.1640    0.446  103.019     247160.0
# 4        0.0552          0.000000    0.1670    0.811   80.924     288600.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
clean_2017 = data_2017[['name', 'artists','danceability','energy','speechiness','liveness','tempo','duration_ms']]
clean_2017.head(5)
# Out:
#                                  name           artists  danceability  energy  \
# 0                        Shape of You        Ed Sheeran         0.825   0.652
# 1                   Despacito - Remix        Luis Fonsi         0.694   0.815
# 2  Despacito (Featuring Daddy Yankee)        Luis Fonsi         0.660   0.786
# 3            Something Just Like This  The Chainsmokers         0.617   0.635
# 4                         I'm the One         DJ Khaled         0.609   0.668
#
#    speechiness  liveness    tempo  duration_ms
# 0       0.0802    0.0931   95.977     233713.0
# 1       0.1200    0.0924   88.931     228827.0
# 2       0.1700    0.1120  177.833     228200.0
# 3       0.0317    0.1640  103.019     247160.0
# 4       0.0367    0.1670   80.924     288600.0

# %%
data_2018 = pd.read_csv(data_2018)
data_2018.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000083     0.552    0.357   77.169     198973.0             4.0
# 1          0.003720     0.123    0.473   75.023     166606.0             4.0
# 2          0.000066     0.131    0.140  159.847     218147.0             4.0
# 3          0.000000     0.112    0.439  140.124     221440.0             4.0
# 4          0.000060     0.396    0.350   91.030     217925.0             4.0

# %%
clean_2018 = data_2018[['name', 'artists','danceability','energy','speechiness','liveness','tempo','duration_ms']]
clean_2018.head(5)
# Out:
#                            name       artists  danceability  energy  \
# 0                    God's Plan         Drake         0.754   0.449
# 1                          SAD!  XXXTENTACION         0.740   0.613
# 2    rockstar (feat. 21 Savage)   Post Malone         0.587   0.535
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559
# 4                In My Feelings         Drake         0.835   0.626
#
#    speechiness  liveness    tempo  duration_ms
# 0       0.1090     0.552   77.169     198973.0
# 1       0.1450     0.123   75.023     166606.0
# 2       0.0898     0.131  159.847     218147.0
# 3       0.1170     0.112  140.124     221440.0
# 4       0.1250     0.396   91.030     217925.0

# %%
#link jn to pg
connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')
